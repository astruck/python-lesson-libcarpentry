# %%
import urllib.request
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/OpenAPC/openapc-de/master/data/fuberlin/APC_FU_Berlin_2015.csv'
apc_file = 'openAPC.csv'

# %%
urllib.request.urlretrieve(url, apc_file)
# Out:
# ('openAPC.csv', <http.client.HTTPMessage at 0x7fd42c71b4c0>)

# %%
apcs = pd.read_csv(apc_file)

# %%
apcs['euro'].describe()
# Out:
# count      61.000000
# mean     1419.608033
# std       456.811349
# min       219.840000
# 25%      1178.420000
# 50%      1410.070000
# 75%      1800.000000
# max      2000.000000
# Name: euro, dtype: float64

# %%
expensive = apcs[['euro', 'publisher', 'journal_full_title']]

# %%
apcs['euro'].hist()
# Out:
# <AxesSubplot:>

# %%
! pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.10.0
# anaconda-project                   0.8.3
# applaunchservices                  0.2.1
# appnope                            0.1.0
# appscript                          1.1.1
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.4.2
# astropy                            4.0.2
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.4
# Babel                              2.8.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.1
# backports.shutil-get-terminal-size 1.0.0
# ...

# %%
! conda list
# Out:
# # packages in environment at /Users/lx/opt/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py38_0
# alabaster                 0.7.12                     py_0
# anaconda                  2020.11                  py38_0
# anaconda-client           1.7.2                    py38_0
# anaconda-navigator        1.10.0                   py38_0
# anaconda-project          0.8.4                      py_0
# applaunchservices         0.2.1                      py_0
# appnope                   0.1.0                 py38_1001
# appscript                 1.1.1            py38haf1e3a3_0
# argh                      0.26.2                   py38_0
# argon2-cffi               20.1.0           py38haf1e3a3_1
# asn1crypto                1.4.0                      py_0
# astroid                   2.4.2                    py38_0
# astropy                   4.0.2            py38haf1e3a3_0
# ...

# %%
expensive.sort(['euro'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-203d5744de1d> in <module>
# ----> 1 expensive.sort(['euro'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort'
